# %%
import sys; 
sys.path.insert(0, '/home/jovyan/.local/lib/python3.12/site-packages')

# %%
import numpy

# %%
import torch

# %%
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import torchvision
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
# !uv pip install torchvision
# Out:
# Using Python 3.12.3 environment at: /home/jovyan/.jupyter
# Resolved 32 packages in 1.01s
# Prepared 2 packages in 267ms
# Installed 2 packages in 547ms
#  + pillow==12.2.0
#  + torchvision==0.27.0
